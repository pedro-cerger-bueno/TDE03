# %% [markdown]
# **GRUPO A) COMB SORT: Faz comparações de elementos que estão a uma distância maior que 1, até que chegue um ponto em que essa distância seja 1. Por causa dessa distância a ser fechada, há sempre um maior número de iterações, visto quantas vezes o loop acontece**

# %% [markdown]
# **Aplicando o Comb sort ao conjunto de 1000** <br>
# ![WhatsApp Image 2024-10-27 at 17.46.21.jpeg](data:image/jpeg;base64,...)
# <br>

# %% [markdown]
# **Aplicando o Comb sort ao conjunto de 10000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Comb sort ao conjunto de 100000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Comb sort ao conjunto de 500000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Comb sort ao conjunto de 1000000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **GRUPO B) MERGE SORT: Baseado ná técnica de dividir e conquistar, dividindo o vetor em sub-vetores, e depois combinando esses sub-vetores em ordem crescente.Pela natureza dessa ordenação, ele sempre realiza a mesma quantidade de trocas, não evitando comparações**

# %% [markdown]
# **Aplicando o Merge sort ao conjunto de 1000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Merge sort ao conjunto de 10000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Merge sort ao conjunto de 100000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Merge sort ao conjunto de 500000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Merge sort ao conjunto de 1000000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **GRUPO B) QUICK SORT: Utiliza a técnica de dividir e conquistar, assim como o Merge sort, porém é caracterizado por sua velocidade e seu uso em listas grandes. Sempre divide em pequenos sub-vetores, diferente do Merge sort**

# %% [markdown]
# **Aplicando o Quick sort ao conjunto de 1000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Quick sort ao conjunto de 10000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Quick sort ao conjunto de 100000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Quick sort ao conjunto de 500000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Quick sort ao conjunto de 1000000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **GRUPO C) TIM SORT: Algoritmo de ordenação padrão para Python e Java, por sua eficiência para diferentes tipos de dados e padrões para listas reais**

# %% [markdown]
# **Aplicando o Tim sort ao conjunto de 1000**
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Tim sort ao conjunto de 10000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Tim sort ao conjunto de 100000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Tim sort ao conjunto de 500000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Aplicando o Tim sort ao conjunto de 1000000** <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **GRÁFICOS (Separados por categorias e tamanho de conjuntos)**

# %% [markdown]
# **CONJUNTO DE 1000**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CONJUNTO DE 10000**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CONJUNTO DE 100000**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CONJUNTO DE 500000**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CONJUNTO DE 1000000**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
